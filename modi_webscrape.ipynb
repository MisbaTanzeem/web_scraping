# %%
import pandas as pd
import requests

# %%
API_KEY="963559fd-f53b-42f7-b313-36d877801117"

# %%
url="https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=1"

# %%
urlist=[]

# %%
for i in range(1,27):
    a="https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page="
    b=str(i)
    c=a+b
    urlist.append(c)

# %%
urlist
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=1',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=2',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=3',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=4',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=5',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=963559fd-f53b-42f7-b313-36d877801117&type=article&page=6',
# ...

# %%
info=[]

# %%
def json(url1):
    web=requests.get(url1)
    x=web.json()
    info.append(x)

# %%
output=[json(url1) for url1 in urlist]

# %%
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 254,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 26,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'world/2024/sep/14/hi-tech-strategic-new-wave-of-kashmir-militant-attacks-before-elections-stuns-indian-forces',
#      'type': 'article',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2024-09-14T12:00:27Z',
#      'webTitle': 'Hi-tech, strategic: new wave of Kashmir militant attacks before elections stuns Indian forces',
# ...

# %%
len(info)
# Out:
# 26

# %%
info[0]['response']['total']
# Out:
# 254

# %%
info[0]['response']['results'][1]['webTitle']
# Out:
# 'These 21st-century demagogues aren’t mavericks – they’ve repeated on us throughout history | George Monbiot'

# %%
finalist=[]

# %%
try:
    for i in range(0,27):
     for j in range(0,10):
         value=dict(webtitle=info[i]['response']['results'][j]['webTitle'],
         sectionname=info[i]['response']['results'][j]['sectionName'],
         publishdate=info[i]['response']['results'][j]['webPublicationDate'])
         finalist.append(value)
except IndexError:
    print("done")
# Out:
# done

# %%
finalist
# Out:
# [{'webtitle': 'Hi-tech, strategic: new wave of Kashmir militant attacks before elections stuns Indian forces',
#   'sectionname': 'World news',
#   'publishdate': '2024-09-14T12:00:27Z'},
#  {'webtitle': 'These 21st-century demagogues aren’t mavericks – they’ve repeated on us throughout history | George Monbiot',
#   'sectionname': 'Opinion',
#   'publishdate': '2024-09-06T05:00:17Z'},
#  {'webtitle': 'Why fascists hate universities | Jason Stanley',
#   'sectionname': 'Opinion',
#   'publishdate': '2024-09-05T17:00:01Z'},
#  {'webtitle': 'Farming the Revolution review – low-key look at Indian farmers’ street-camp protests',
#   'sectionname': 'Film',
#   'publishdate': '2024-08-26T12:00:31Z'},
#  {'webtitle': 'Ukraine war briefing: Biden and Zelenskiy talk as Ukraine prepares to mark independence day',
#   'sectionname': 'World news',
#   'publishdate': '2024-08-24T05:09:29Z'},
#  {'webtitle': 'Five of the best books about Indian politics',
#   'sectionname': 'Books',
# ...

# %%
datanew=pd.DataFrame(finalist)

# %%
datanew
# Out:
#                                               webtitle sectionname  \
# 0    Hi-tech, strategic: new wave of Kashmir milita...  World news
# 1    These 21st-century demagogues aren’t mavericks...     Opinion
# 2       Why fascists hate universities | Jason Stanley     Opinion
# 3    Farming the Revolution review – low-key look a...        Film
# 4    Ukraine war briefing: Biden and Zelenskiy talk...  World news
# ..                                                 ...         ...
# 513  Trump social media ban sparks calls for action...       Media
# 514  Mahatma Gandhi's killer venerated as Hindu nat...  World news
# 515  India begins world's biggest Covid vaccination...  World news
# 516  India's supreme court gives go-ahead for contr...  World news
# 517  India's approval of covid vaccines triggers ma...  World news
#
#               publishdate
# 0    2024-09-14T12:00:27Z
# 1    2024-09-06T05:00:17Z
# 2    2024-09-05T17:00:01Z
# 3    2024-08-26T12:00:31Z
# ...

# %%
datanew.to_csv('news.csv',index=False)

# %%
ff=pd.read_csv('news.csv')

# %%
ff
# Out:
#                                               webtitle sectionname  \
# 0    Hi-tech, strategic: new wave of Kashmir milita...  World news
# 1    These 21st-century demagogues aren’t mavericks...     Opinion
# 2       Why fascists hate universities | Jason Stanley     Opinion
# 3    Farming the Revolution review – low-key look a...        Film
# 4    Ukraine war briefing: Biden and Zelenskiy talk...  World news
# ..                                                 ...         ...
# 513  Trump social media ban sparks calls for action...       Media
# 514  Mahatma Gandhi's killer venerated as Hindu nat...  World news
# 515  India begins world's biggest Covid vaccination...  World news
# 516  India's supreme court gives go-ahead for contr...  World news
# 517  India's approval of covid vaccines triggers ma...  World news
#
#               publishdate
# 0    2024-09-14T12:00:27Z
# 1    2024-09-06T05:00:17Z
# 2    2024-09-05T17:00:01Z
# 3    2024-08-26T12:00:31Z
# ...
